# %% [markdown]
# # Assignment 1 - Appstore data

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load data
app_df=pd.read_csv('googleplaystore.csv')
reviews_df=pd.read_csv('googleplaystore_user_reviews.csv')

# %%
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
app_columns=list(app_df.columns)
app_columns
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#chech what percentage we miss from the data
(app_df.isnull().sum()/len(app_df)*100).sort_values(ascending=False)
# Out:
# Rating            13.596532
# Current Ver        0.073794
# Android Ver        0.027673
# Type               0.009224
# Content Rating     0.009224
# App                0.000000
# Category           0.000000
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Price              0.000000
# Genres             0.000000
# Last Updated       0.000000
# dtype: float64

# %%
#fill rating nan values with mean
app_df["Rating"]=app_df[['Rating']].fillna(app_df['Rating'].mean())

# %%
# check if rating is indeed imputed
(app_df.isnull().sum()/len(app_df)*100).sort_values(ascending=False)
# Out:
# Current Ver       0.073794
# Android Ver       0.027673
# Type              0.009224
# Content Rating    0.009224
# App               0.000000
# Category          0.000000
# Rating            0.000000
# Reviews           0.000000
# Size              0.000000
# Installs          0.000000
# Price             0.000000
# Genres            0.000000
# Last Updated      0.000000
# dtype: float64

# %%
app_df.Rating.describe()
# Out:
# count    10841.000000
# mean         4.193338
# std          0.499557
# min          1.000000
# 25%          4.100000
# 50%          4.200000
# 75%          4.500000
# max         19.000000
# Name: Rating, dtype: float64

# %%
#locate the odd one 
app_df.sort_values('Rating', ascending=False)
# Out:
#                                            App         Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
# 9503                            Pyaar Ek Dhoka           FAMILY     5.0
# 9282                                 EF Events           EVENTS     5.0
# 4477                 Android P Style Icon Pack  PERSONALIZATION     5.0
# 8159                                 CZ Kompas            TOOLS     5.0
# ...                                        ...              ...     ...
# 8875                            DT future1 cam            TOOLS     1.0
# 4127                         Speech Therapy: F           FAMILY     1.0
# 10400  Familial Hypercholesterolaemia Handbook          MEDICAL     1.0
# 7383                            Thistletown CI     PRODUCTIVITY     1.0
# 8820                            DS Creator 2.0            TOOLS     1.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
# 9503       18    1.3M      50+  Free         0       Everyone
# 9282        7    4.4M     100+  Free         0           Teen
# 4477        1     60M     100+  Paid     $0.99       Everyone
# 8159        2    3.5M      10+  Free         0       Everyone
# ...       ...     ...      ...   ...       ...            ...
# 8875        1     24M      50+  Free         0       Everyone
# 4127        1     16M      10+  Paid     $2.99       Everyone
# 10400       2     33M     100+  Free         0       Everyone
# 7383        1    6.6M     100+  Free         0       Everyone
# 8820        2    4.4M     500+  Free         0       Everyone
#
#                   Genres       Last Updated         Current Ver  \
# 10472  February 11, 2018             1.0.19          4.0 and up
# 9503              Casual  February 13, 2018                 1.0
# 9282              Events    October 5, 2017  Varies with device
# 4477     Personalization      June 16, 2018                 1.0
# 8159               Tools       July 9, 2018                 1.1
# ...                  ...                ...                 ...
# 8875               Tools     March 27, 2018                 3.1
# 4127           Education    October 7, 2016                 1.0
# 10400            Medical       July 2, 2018               2.0.1
# 7383        Productivity     March 15, 2018                41.9
# 8820               Tools     March 23, 2018        2.0.180226.1
#
#               Android Ver
# 10472                 NaN
# 9503           4.3 and up
# 9282   Varies with device
# 4477           4.1 and up
# 8159           4.0 and up
# ...                   ...
# 8875           2.2 and up
# 4127         2.3.3 and up
# 10400          4.1 and up
# 7383           4.1 and up
# 8820           4.0 and up
#
# [10841 rows x 13 columns]

# %%
app_df=app_df.dropna()

# %%
#final check for missing values etc
(app_df.isnull().sum()/len(app_df)*100).sort_values(ascending=False)
# Out:
# App               0.0
# Category          0.0
# Rating            0.0
# Reviews           0.0
# Size              0.0
# Installs          0.0
# Type              0.0
# Price             0.0
# Content Rating    0.0
# Genres            0.0
# Last Updated      0.0
# Current Ver       0.0
# Android Ver       0.0
# dtype: float64

# %%
# cheking for duplicates
app_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Length: 10829, dtype: bool

# %%
#drop duplicates
app_df.drop_duplicates(subset=['App'], inplace=True)

# %% [markdown]
# # dealing with data types

# %%
#changing reviews to a float
app_df['Reviews']=app_df["Reviews"].astype(float)

# %%
# last updated to date time
app_df["Last Updated"]= pd.to_datetime(app_df["Last Updated"])

# %%
# dealing with installs
app_df['Installs_float']=app_df['Installs'].apply(lambda x: x.replace('+',''))

# %%
app_df['Installs_float']=app_df['Installs_float'].apply(lambda x: x.replace(',',''))

# %%
app_df['Installs_float'] = app_df['Installs_float'].astype(float)

# %%
# dealing with price
app_df["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
app_df['Price']=app_df['Price'].apply(lambda x: x.replace('$',''))

# %%
app_df['Price']=pd.to_numeric(app_df['Price'])

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   float64
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   float64
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   datetime64[ns]
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
#  13  Installs_float  9648 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(9)
# memory usage: 1.1+ MB

# %%
# dealing with size

app_df['Size'].value_counts()['Varies with device']

app_df = app_df[app_df.Size != 'Varies with device']


#dict for replace
_prefix = {'k': 1e3,    # thousand
           'M': 1e6,    # million
           'B': 1e9,    # billion
           
}

#all keys of dict separated by | (or)
k = '|'.join(_prefix.keys())

#extract values to new df
df1 = app_df['Size'].str.extract('(?P<a>[0-9.]*)(?P<b>' + k +')*', expand=True)

#convert numeric column to float
df1.a = df1.a.astype(float)

#map values by dictionary, replace NaN (no prefix) to 1
df1.b = df1.b.map(_prefix).fillna(1)

#multiple columns together
app_df['Size_int'] = df1.a.mul(df1.b).astype(int)

# %%
app_df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#          Rating   Reviews  Size     Installs  Type  Price Content Rating  \
# 0      4.100000     159.0   19M      10,000+  Free    0.0       Everyone
# 1      3.900000     967.0   14M     500,000+  Free    0.0       Everyone
# 2      4.700000   87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3      4.500000  215644.0   25M  50,000,000+  Free    0.0           Teen
# 4      4.300000     967.0  2.8M     100,000+  Free    0.0       Everyone
# ...         ...       ...   ...          ...   ...    ...            ...
# 10835  4.193338       0.0  9.6M          10+  Free    0.0       Everyone
# 10836  4.500000      38.0   53M       5,000+  Free    0.0       Everyone
# 10837  5.000000       4.0  3.6M         100+  Free    0.0       Everyone
# 10838  4.193338       3.0  9.5M       1,000+  Free    0.0       Everyone
# 10840  4.500000  398307.0   19M  10,000,000+  Free    0.0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design   2018-01-07               1.0.0
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0
# 2                   Art & Design   2018-08-01               1.2.4
# 3                   Art & Design   2018-06-08  Varies with device
# 4        Art & Design;Creativity   2018-06-20                 1.1
# ...                          ...          ...                 ...
# 10835                   Business   2016-09-29               1.1.5
# 10836                  Education   2017-07-25                1.48
# 10837                  Education   2018-07-06                 1.0
# 10838                    Medical   2017-01-20                 1.0
# 10840                  Lifestyle   2018-07-25  Varies with device
#
#               Android Ver  Installs_float  Size_int
# 0            4.0.3 and up         10000.0  19000000
# 1            4.0.3 and up        500000.0  14000000
# 2            4.0.3 and up       5000000.0   8700000
# 3              4.2 and up      50000000.0  25000000
# 4              4.4 and up        100000.0   2800000
# ...                   ...             ...       ...
# 10835          4.0 and up            10.0   9600000
# 10836          4.1 and up          5000.0  53000000
# 10837          4.1 and up           100.0   3600000
# 10838          2.2 and up          1000.0   9500000
# 10840  Varies with device      10000000.0  19000000
#
# [8422 rows x 15 columns]

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8422 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8422 non-null   object
#  1   Category        8422 non-null   object
#  2   Rating          8422 non-null   float64
#  3   Reviews         8422 non-null   float64
#  4   Size            8422 non-null   object
#  5   Installs        8422 non-null   object
#  6   Type            8422 non-null   object
#  7   Price           8422 non-null   float64
#  8   Content Rating  8422 non-null   object
#  9   Genres          8422 non-null   object
#  10  Last Updated    8422 non-null   datetime64[ns]
#  11  Current Ver     8422 non-null   object
#  12  Android Ver     8422 non-null   object
#  13  Installs_float  8422 non-null   float64
#  14  Size_int        8422 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# # data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0   19M      10,000+  Free    0.0       Everyone
# 1     967.0   14M     500,000+  Free    0.0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644.0   25M  50,000,000+  Free    0.0           Teen
# 4     967.0  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    Installs_float  Size_int
# 0         10000.0  19000000
# 1        500000.0  14000000
# 2       5000000.0   8700000
# 3      50000000.0  25000000
# 4        100000.0   2800000

# %%
# Quick overview of the df with sns pairplot
import seaborn as sns
sns.pairplot(app_df)

# %%
numerical_app_df=app_df[['Rating', 'Reviews', 'Price', 'Installs_float','Size_int']]
numerical_app_df
# Out:
#          Rating   Reviews  Price  Installs_float  Size_int
# 0      4.100000     159.0    0.0         10000.0  19000000
# 1      3.900000     967.0    0.0        500000.0  14000000
# 2      4.700000   87510.0    0.0       5000000.0   8700000
# 3      4.500000  215644.0    0.0      50000000.0  25000000
# 4      4.300000     967.0    0.0        100000.0   2800000
# ...         ...       ...    ...             ...       ...
# 10835  4.193338       0.0    0.0            10.0   9600000
# 10836  4.500000      38.0    0.0          5000.0  53000000
# 10837  5.000000       4.0    0.0           100.0   3600000
# 10838  4.193338       3.0    0.0          1000.0   9500000
# 10840  4.500000  398307.0    0.0      10000000.0  19000000
#
# [8422 rows x 5 columns]

# %%
#looking at correlation
sns.heatmap(numerical_app_df.corr(),cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
# the histogram of the rating data
n, bins, patches = plt.hist(app_df['Rating'], 10, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Rating Score')
plt.title('Histogram of Rating (Rating Distribution)')
plt.grid(True)
plt.show()

# %%
# the histogram of the reviews data
n, bins, patches = plt.hist(app_df['Reviews'], 5, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Reviews')
plt.title('Histogram of Reviews (Reviews Distribution)')
plt.grid(True)
plt.show()

# %%
# the histogram of the price data
n, bins, patches = plt.hist(app_df['Price'], 10, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Price')
plt.title('Price Distribution)')
plt.grid(True)
plt.show()

# %%
#boxplot Rating
fig, ax = plt.subplots()
ax.boxplot(app_df['Rating'])
ax.set_title('rating')

plt.show()


#boxplot reviews
fig, ax = plt.subplots()
ax.boxplot(app_df['Reviews'])
ax.set_title('reviews')
plt.show()


#boxplot installs
fig, ax = plt.subplots()
ax.boxplot(app_df['Installs_float'])
ax.set_title('installs')
plt.show()


#boxplot size
fig, ax = plt.subplots()
ax.boxplot(app_df['Size_int'])
ax.set_title('size')
plt.show()


#boxplot price
fig, ax = plt.subplots()
ax.boxplot(app_df['Price'])
ax.set_title('price')
plt.show()

# %%
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0   19M      10,000+  Free    0.0       Everyone
# 1     967.0   14M     500,000+  Free    0.0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644.0   25M  50,000,000+  Free    0.0           Teen
# 4     967.0  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0  4.0.3 and up
# 2               Art & Design   2018-08-01               1.2.4  4.0.3 and up
# 3               Art & Design   2018-06-08  Varies with device    4.2 and up
# 4    Art & Design;Creativity   2018-06-20                 1.1    4.4 and up
#
#    Installs_float  Size_int
# 0         10000.0  19000000
# 1        500000.0  14000000
# 2       5000000.0   8700000
# 3      50000000.0  25000000
# 4        100000.0   2800000

# %%
# free vs paid apps
sns.countplot(data=app_df,
              x=app_df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
# free vs paid apps
sns.countplot(data=app_df,
              x=app_df['Content Rating'])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
# finding the most popular genres
genres=app_df.groupby('Genres')

# %%
top_10_popular_genres=genres[['App']].count().sort_values('App', ascending=False).head(10)
top_10_popular_genres
# Out:
#                  App
# Genres
# Tools            729
# Entertainment    505
# Education        469
# Business         376
# Medical          368
# Personalization  349
# Lifestyle        333
# Finance          299
# Productivity     291
# Sports           291

# %%
names=['Tools','Entertainment','Education','Business','Medical','Personalization','Lifestyle','Finance','Productivity','Sports']

# %%
top_10_popular_genres.plot(kind='bar', title='Top 10 Genres')
# Out:
# <AxesSubplot:title={'center':'Top 10 Genres'}, xlabel='Genres'>

# %%
topgenres_df=app_df.loc[ app_df.Genres.isin(names), : ]
topgenres_df.reset_index(inplace=False)
topgenres_df
# Out:
#                                                      App   Category    Rating  \
# 190                                 ADP Mobile Solutions   BUSINESS  4.300000
# 194               OfficeSuite : Free Office + PDF Editor   BUSINESS  4.300000
# 195                                         USPS MOBILE®   BUSINESS  3.900000
# 196                           Job Search by ZipRecruiter   BUSINESS  4.800000
# 197    Curriculum vitae App CV Builder Free Resume Maker   BUSINESS  4.500000
# ...                                                  ...        ...       ...
# 10835                                           FR Forms   BUSINESS  4.193338
# 10836                                   Sya9a Maroc - FR     FAMILY  4.500000
# 10837                   Fr. Mike Schmitz Audio Teachings     FAMILY  5.000000
# 10838                             Parkinson Exercices FR    MEDICAL  4.193338
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE  4.500000
#
#          Reviews  Size      Installs  Type  Price Content Rating     Genres  \
# 190      85185.0   29M    5,000,000+  Free    0.0       Everyone   Business
# 194    1002861.0   35M  100,000,000+  Free    0.0       Everyone   Business
# 195      16589.0  9.1M    1,000,000+  Free    0.0       Everyone   Business
# 196     148945.0   25M    1,000,000+  Free    0.0       Everyone   Business
# 197       4458.0  3.9M      500,000+  Free    0.0       Everyone   Business
# ...          ...   ...           ...   ...    ...            ...        ...
# 10835        0.0  9.6M           10+  Free    0.0       Everyone   Business
# 10836       38.0   53M        5,000+  Free    0.0       Everyone  Education
# 10837        4.0  3.6M          100+  Free    0.0       Everyone  Education
# 10838        3.0  9.5M        1,000+  Free    0.0       Everyone    Medical
# 10840   398307.0   19M   10,000,000+  Free    0.0       Everyone  Lifestyle
#
#       Last Updated         Current Ver         Android Ver  Installs_float  \
# 190     2018-07-17               3.4.2          5.0 and up       5000000.0
# 194     2018-08-02           9.7.14188          4.1 and up     100000000.0
# 195     2018-06-14              4.9.10        4.0.3 and up       1000000.0
# 196     2018-07-19               5.2.8          5.0 and up       1000000.0
# 197     2018-07-08                 3.3          4.1 and up        500000.0
# ...            ...                 ...                 ...             ...
# 10835   2016-09-29               1.1.5          4.0 and up            10.0
# 10836   2017-07-25                1.48          4.1 and up          5000.0
# 10837   2018-07-06                 1.0          4.1 and up           100.0
# 10838   2017-01-20                 1.0          2.2 and up          1000.0
# 10840   2018-07-25  Varies with device  Varies with device      10000000.0
#
#        Size_int
# 190    29000000
# 194    35000000
# 195     9100000
# 196    25000000
# 197     3900000
# ...         ...
# 10835   9600000
# 10836  53000000
# 10837   3600000
# 10838   9500000
# 10840  19000000
#
# [4010 rows x 15 columns]

# %%
mean_rating_topgenres_df=topgenres_df[["Rating", "Reviews","Genres"]].groupby(by=['Genres']).mean()
mean_rating_topgenres_df
# Out:
#                    Rating        Reviews
# Genres
# Business         4.136101   11678.577128
# Education        4.277783    9555.825160
# Entertainment    4.102800   51005.198020
# Finance          4.116812   29664.347826
# Lifestyle        4.110411   22608.648649
# Medical          4.170980    2815.750000
# Personalization  4.296276   80425.229226
# Productivity     4.146897   79852.931271
# Sports           4.206095  190567.673540
# Tools            4.032383  114422.377229

# %%
# Average Rating per top 10 Genre
sns.scatterplot(data=mean_rating_topgenres_df, x='Rating', y='Reviews', hue='Genres')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
# Average Rating per top 10 Genre
sns.scatterplot(data=mean_rating_topgenres_df, x='Rating', y='Installs_float', hue='Genres')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jv/yk7cpcx97ln8wgt109nxk6c00000gn/T/ipykernel_43915/4294870438.py in <module>
#       1 # Average Rating per top 10 Genre
# ----> 2 sns.scatterplot(data=mean_rating_topgenres_df, x='Rating', y='Installs_float', hue='Genres')
#       3 plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `Installs_float` for parameter `y`

# %%
n, bins, patches = plt.hist(topgenres_df['Rating'], 8, density=True, facecolor='g')

plt.xlabel('Rating Score')
plt.title('Mean Rating Distribution from top genres')
plt.grid(True)
plt.show()

# %% [markdown]
# # Suggestion
#
# - Entering Tools genre --> low ratings while high popularity/demand.
#
# --> future research to see how installs are correlated with reviews en include the reviews sentiments
